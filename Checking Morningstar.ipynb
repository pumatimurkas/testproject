# %%
import requests

url = "https://morningstar1.p.rapidapi.com/fundamentals/yearly/cashflow-statement/restated"

querystring = {"Mic":"XNAS","Ticker":"MSFT"}

headers = {
    'x-rapidapi-host': "morningstar1.p.rapidapi.com",
    'x-rapidapi-key': "702dbf1af7msh792e7b98d7cd891p1aec91jsna2bd5d1291cf",
    'accept': "string"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"total":5,"offset":0,"results":[{"periodEndDate":"2015-06-30","sections":[{"sectionHeader":"&NBSP;","lineItems":[{"label":"CASH AT BEGINNING OF PERIOD","value":8669000000},{"label":"CASH AT END OF PERIOD","value":5595000000},{"label":"EFFECT OF EXCHANGE RATE CHANGES","value":-73000000},{"label":"NET CHANGE IN CASH","value":-3074000000}],"subsections":[{"sectionHeader":"CASH FLOWS FROM FINANCING ACTIVITIES","lineItems":[{"label":"COMMON STOCK ISSUED","value":634000000},{"label":"COMMON STOCK REPURCHASED","value":-14443000000},{"label":"DEBT ISSUED","value":10680000000},{"label":"DEBT REPAYMENT","value":-1500000000},{"label":"DIVIDEND PAID","value":-9882000000},{"label":"DIVIDEND PAYABLE","value":null},{"label":"EXCESS TAX BENEFIT FROM STOCK BASED COMPENSATION","value":null},{"label":"OTHER FINANCING ACTIVITIES","value":4843000000},{"label":"PREFERRED STOCK ISSUED","value":null},{"label":"PREFERRED STOCK REPAID","value":null},{"label":"WARRANT ISSUED","value":null}],"subsections":[],"
# ...
